# %% [markdown]
# #LibrariesImported

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window

# %% [markdown]
# #DataframesCreated

# %%
#FunctiontocreateDFfromCSVFiles
def readcsvtoDF(path):
    return spark.read.option("header",True).csv(path)

#FunctionToGroupByandCountDistinctCrash_ID
def agg_crash_id_function(df):
    display(df.select(col('Crash_ID')).agg(countDistinct(col('CRASH_ID')).alias("Count")))

# %%
# mntPoint Common input mount point for all source paths
mntPoint="/FileStore/tables/"
charges_df=readcsvtoDF(mntPoint+"Charges_use.csv")
Damages_df=readcsvtoDF(mntPoint+"Damages_use.csv")
Endorse_df=readcsvtoDF(mntPoint+"Endorse_use.csv")
Primary_Person_df=readcsvtoDF(mntPoint+"Primary_Person_use.csv")
Restrict_use_df=readcsvtoDF(mntPoint+"Restrict_use.csv")
Units_use_df=readcsvtoDF(mntPoint+"Units_use.csv")

# %% [markdown]
# #Analysis 1: Find the number of crashes (accidents) in which number of persons killed are male?

# %%
# Gender = Male and Status=KILLED . counted those number of crashes as multiple person could get killed in same crash.
agg_crash_id_function(Primary_Person_df.where("PRSN_GNDR_ID='MALE' and PRSN_INJRY_SEV_ID='KILLED'"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Count</th></tr></thead><tbody><tr><td>180</td></tr></tbody></table></div>

# %% [markdown]
# #Analysis 2: How many two wheelers are booked for crashes?

# %%
# After Checking VEH_BODY_STYL_ID , Came to conclusion only option for two wheeler was MOTORCYCLE.
agg_crash_id_function(Units_use_df.where("VEH_BODY_STYL_ID='MOTORCYCLE'"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Count</th></tr></thead><tbody><tr><td>754</td></tr></tbody></table></div>

# %% [markdown]
# #Analysis 3: Which state has highest number of accidents in which females are involved?

# %%
Primary_Person_df\
.where("PRSN_GNDR_ID='FEMALE'")\
.groupBy(col('DRVR_LIC_STATE_ID'))\
.agg(countDistinct(col('CRASH_ID')).alias("Count"))\
.orderBy(col('Count').desc())\
.limit(1)\
.show()
# Out:
# +-----------------+-----+
# |DRVR_LIC_STATE_ID|Count|
# +-----------------+-----+
# |            Texas|42138|
# +-----------------+-----+

# %% [markdown]
# #Analysis 4: Which are the Top 5th to 15th VEH_MAKE_IDs that contribute to a largest number of injuries including death

# %%
# found out Tot_injury_cnt where dealth_cnt is present or not equal to 0 . and putting a window function to find out top 5 to 15th
Units_use_df1=Units_use_df\
.where("DEATH_CNT!=0")\
.groupBy(col("VEH_MAKE_ID"))\
.agg(sum(col("TOT_INJRY_CNT")).cast("Int").alias("TOT_INJRY_CNT"))\

windowSpec=Window.orderBy(col("TOT_INJRY_CNT").desc())

Units_use_df1.withColumn("RNK",row_number().over(windowSpec)).where("RNK Between 5 and 15").show(truncate=True)
# Out:
# +-----------+-------------+---+
# |VEH_MAKE_ID|TOT_INJRY_CNT|RNK|
# +-----------+-------------+---+
# |     TOYOTA|            9|  5|
# |   CHRYSLER|            6|  6|
# |        KIA|            4|  7|
# | OLDSMOBILE|            3|  8|
# |      HONDA|            3|  9|
# |    HYUNDAI|            2| 10|
# |   PLYMOUTH|            2| 11|
# |      ACURA|            1| 12|
# | VOLKSWAGEN|            1| 13|
# |     YAMAHA|            1| 14|
# |   CADILLAC|            1| 15|
# +-----------+-------------+---+

# %% [markdown]
# #Analysis 5: For all the body styles involved in crashes, mention the top ethnic user group of each unique body style

# %%
# For finding out the Vehicle Body type used Units table and for ethnicity used PrimaryPerson table .
# for counting the number of ethinicity for each body type joined table on crash_id and Unit_NBR granularity
# After Calculating for each for body type windowed on the basis of counts present for each body type
U=Units_use_df.alias("U")
P=Primary_Person_df.alias("P")
UandP=U.join(P,[U.CRASH_ID==P.CRASH_ID,U.UNIT_NBR==P.UNIT_NBR],"Inner")\
.select(U.VEH_BODY_STYL_ID,P.PRSN_ETHNICITY_ID)\
.groupBy(U.VEH_BODY_STYL_ID,P.PRSN_ETHNICITY_ID)\
.agg(count("*").alias("count_of_records"))\
# .show(truncate=False)

windowSpec1=Window.partitionBy("VEH_BODY_STYL_ID").orderBy(col("count_of_records").desc())

display(UandP.withColumn("Row_Number",row_number().over(windowSpec1)).where("Row_Number=1"))
# .show(truncate=False)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VEH_BODY_STYL_ID</th><th>PRSN_ETHNICITY_ID</th><th>count_of_records</th><th>Row_Number</th></tr></thead><tbody><tr><td>AMBULANCE</td><td>WHITE</td><td>55</td><td>1</td></tr><tr><td>BUS</td><td>HISPANIC</td><td>158</td><td>1</td></tr><tr><td>FARM EQUIPMENT</td><td>WHITE</td><td>27</td><td>1</td></tr><tr><td>FIRE TRUCK</td><td>WHITE</td><td>64</td><td>1</td></tr><tr><td>MOTORCYCLE</td><td>WHITE</td><td>499</td><td>1</td></tr><tr><td>NA</td><td>WHITE</td><td>294</td><td>1</td></tr><tr><td>NEV-NEIGHBORHOOD ELECTRIC VEHICLE</td><td>WHITE</td><td>5</td><td>1</td></tr><tr><td>NOT REPORTED</td><td>WHITE</td><td>2</td><td>1</td></tr><tr><td>OTHER  (EXPLAIN IN NARRATIVE)</td><td>WHITE</td><td>216</td><td>1</td></tr><tr><td>PASSENGER CAR, 2-DOOR</td><td>WHITE</td><td>4716</td><td>1</td></tr><tr><td>PASSENGER CAR, 4-DOOR</td><td>WHITE</td><td>25351</td><td>1</td></tr><tr><td>PICKUP</td><td>WHITE</td><td>19117</td><td>1</td></tr><tr><td>POLICE CAR/TRUCK</td><td>WHITE</td><td>182</td><td>1</td></tr><tr><td>POLICE MOTORCYCLE</td><td>WHITE</td><td>2</td><td>1</td></tr><tr><td>SPORT UTILITY VEHICLE</td><td>WHITE</td><td>15497</td><td>1</td></tr><tr><td>TRUCK</td><td>WHITE</td><td>1814</td><td>1</td></tr><tr><td>TRUCK TRACTOR</td><td>WHITE</td><td>2560</td><td>1</td></tr><tr><td>UNKNOWN</td><td>UNKNOWN</td><td>843</td><td>1</td></tr><tr><td>VAN</td><td>WHITE</td><td>2212</td><td>1</td></tr><tr><td>YELLOW SCHOOL BUS</td><td>BLACK</td><td>106</td><td>1</td></tr></tbody></table></div>
# Output can only be rendered in Databricks

# %% [markdown]
# #Analysis 6: Among the crashed cars, what are the Top 5 Zip Codes with highest number crashes with alcohols as the contributing factor to a crash (Use Driver Zip Code)

# %%
# Assumed all crashed as Cars , for alcohol took PRSN_ALC_RSLT_ID='Positive' and Contributing Factor consisting of character as ALCOHOL and DRINKING IN all 3 contributing attributes
Units_with_AlcoholASContributer=Units_use_df.where("CONTRIB_FACTR_1_ID like ('%ALCOHOL%') or CONTRIB_FACTR_1_ID like ('%DRINKING%')\
OR CONTRIB_FACTR_2_ID like ('%ALCOHOL%') or CONTRIB_FACTR_2_ID like ('%DRINKING%')\
OR CONTRIB_FACTR_P1_ID like ('%ALCOHOL%') or CONTRIB_FACTR_P1_ID like ('%DRINKING%')").select("CRASH_ID","CONTRIB_FACTR_1_ID","CONTRIB_FACTR_2_ID","CONTRIB_FACTR_P1_ID")

UNITALCOHOLCONTR=Units_with_AlcoholASContributer.alias("UNITALCOHOLCONTR")
PPDF=Primary_Person_df.alias("PPDF")
Primary_Person_df.join(Units_with_AlcoholASContributer,[PPDF.CRASH_ID==UNITALCOHOLCONTR.CRASH_ID],"INNER")\
.where("PRSN_ALC_RSLT_ID='Positive' and DRVR_ZIP is not null")\
.groupBy(col("DRVR_ZIP"))\
.agg(count("*").alias("count_records"))\
.orderBy(col("count_records").desc())\
.limit(5)\
.show()
# Out:
# +--------+-------------+
# |DRVR_ZIP|count_records|
# +--------+-------------+
# |   78521|           53|
# |   76010|           47|
# |   78130|           29|
# |   78550|           28|
# |   78240|           28|
# +--------+-------------+

# %% [markdown]
# #Analysis 7: Count of Distinct Crash IDs where No Damaged Property was observed and Damage Level (VEH_DMAG_SCL~) is above 4 and car avails Insurance

# %%
# taken Units and kept Units into left join with damages and found out those crash_ID not present in Damage table . and made a distinct count over those
# for SCL in problem desc it was mentioned SCL~ so taken both 1 and 2 for for > 4
# For Insurance only attribute FIN_RESP_TYPE_ID was having data related to insurance so taken them all .
U1=Units_use_df.alias('U1')
D=Damages_df.alias('D')
U1.join(D,[U1.CRASH_ID==D.CRASH_ID],"LEFT")\
.where("D.Damaged_property is null AND \
split(U1.VEH_DMAG_SCL_1_ID,' ')[1]>4 AND \
split(U1.VEH_DMAG_SCL_2_ID,' ')[1]>4 AND \
FIN_RESP_TYPE_ID like '%INSURANCE%'")\
.select("U1.CRASH_ID","VEH_DMAG_SCL_1_ID","VEH_DMAG_SCL_2_ID","FIN_RESP_TYPE_ID")\
.agg(countDistinct(col('U1.CRASH_ID')).alias("Distinct_CrashID_Count"))\
.show(truncate=False)
# Out:
# +----------------------+
# |Distinct_CrashID_Count|
# +----------------------+
# |1184                  |
# +----------------------+

# %% [markdown]
# #Analysis 8: Determine the Top 5 Vehicle Makes where drivers are charged with speeding related offences, has licensed Drivers, uses top 10 used vehicle colours and has car licensed with the Top 25 states with highest number of offences (to be deduced from the data)

# %%
units_with_top_25_offences=Units_use_df\
.groupBy("VEH_LIC_STATE_ID")\
.agg(countDistinct("CRASH_ID").alias("total_offences"))\
.orderBy(col("total_offences").desc())\
.limit(25)\
.select("VEH_LIC_STATE_ID")\
.rdd\
.map(lambda x:x[0])\
.collect()
print(units_with_top_25_offences)
# Out:
# ['TX', 'NA', 'UN', 'OK', 'LA', 'NM', 'MX', 'CA', 'FL', 'AR', 'IN', 'IL', 'TN', 'AZ', 'MS', 'CO', 'GA', 'KS', 'MO', 'NC', 'AL', 'OH', 'MI', 'MN', '98']

# %%
units_with_top_10_colors=Units_use_df\
.where("VEH_COLOR_ID!='NA'")\
.groupBy("VEH_COLOR_ID")\
.agg(count(col("CRASH_ID")).alias("total_colors_being_used"))\
.orderBy(col("total_colors_being_used").desc())\
.limit(10)\
.select("VEH_COLOR_ID")\
.rdd\
.map(lambda x:x[0])\
.collect()
print(units_with_top_10_colors)
# Out:
# ['WHI', 'BLK', 'SIL', 'GRY', 'BLU', 'RED', 'GRN', 'MAR', 'TAN', 'GLD']

# %%
charges_with_speed=charges_df.where("lower(Charge) like '%speed%'").select("CRASH_ID","CHARGE")
display(charges_with_speed)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CRASH_ID</th><th>CHARGE</th></tr></thead><tbody><tr><td>14838834</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14838972</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14838977</td><td>UNSAFE SPEED</td></tr><tr><td>14839233</td><td>UNSAFE SPEED</td></tr><tr><td>14839240</td><td>FAILED TO CONTROL SPEED ACCIDENT</td></tr><tr><td>14839272</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14839342</td><td>FAILED TO CONTROL SPEED</td></tr><tr><td>14839404</td><td>FAILED TO CONTROL SPEED</td></tr><tr><td>14839510</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14839519</td><td>UNSAFE SPEED</td></tr><tr><td>14839675</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14839713</td><td>FAILURE TO CONTROL SPEED</td></tr><tr><td>14839721</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14839735</td><td>FAILURE TO CONTROL SPEED</td></tr><tr><td>14839850</td><td>UNSAFE SPEED</td></tr><tr><td>14839875</td><td>FAILED TO CONTROL SPEED (ACC)</td></tr><tr><td>14839880</td><td>FAIL TO CONTROL SPEED (ACCIDENT)</td></tr><tr><td>14839939</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14839998</td><td>UNSAFE SPEED</td></tr><tr><td>14840064</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14840065</td><td>UNSAFE SPEED</td></tr><tr><td>14840118</td><td>FAILURE TO CONTROL SPEED</td></tr><tr><td>14840230</td><td>UNSAFE SPEED</td></tr><tr><td>14840262</td><td>UNSAFE SPEED</td></tr><tr><td>14840269</td><td>FAILURE TO CONTROL SPEED</td></tr><tr><td>14840277</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14840303</td><td>FAILED TO CONTROL SPEED (ACCIDENT)</td></tr><tr><td>14840523</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14840582</td><td>FAILURE TO CONTROL SPEED</td></tr><tr><td>14840656</td><td>FAILED TO CONTROL SPEED</td></tr><tr><td>14840731</td><td>FAILURE TO CONTROL SPEED</td></tr><tr><td>14840829</td><td>FAILURE TO CONTROL SPEED</td></tr><tr><td>14840905</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14841006</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14841039</td><td>FAIL TO CONTROL SPEED ACC</td></tr><tr><td>14841166</td><td>FAILURE TO CONTROL SPEED</td></tr><tr><td>14841278</td><td>UNSAFE SPEED</td></tr><tr><td>14841503</td><td>FAILURE TO CONTROL SPEED - ACC</td></tr><tr><td>14841715</td><td>FAILURE TO CONTROL SPEED</td></tr><tr><td>14841737</td><td>UNSAFE SPEED</td></tr><tr><td>14841764</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14841772</td><td>FAILED TO CONTROL SPEED</td></tr><tr><td>14841851</td><td>FAILED TO CONTROL SPEED</td></tr><tr><td>14841893</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14841897</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14841944</td><td>FAILURE TO CONTROL SPEED</td></tr><tr><td>14842140</td><td>UNSAFE SPEED (WEATHER CONDITIONS)</td></tr><tr><td>14842235</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14842382</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14842445</td><td>FAILED TO CONTROL SPEED</td></tr><tr><td>14842445</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14842449</td><td>FAILED TO CONTROL SPEED</td></tr><tr><td>14842453</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14842539</td><td>FAILURE TO CONTROL SPEED (ACC)</td></tr><tr><td>14842539</td><td>FAILURE TO CONTROL SPEED (ACC)</td></tr><tr><td>14842539</td><td>FAILURE TO CONTROL SPEED (ACC)</td></tr><tr><td>14842619</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14842649</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14842791</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14842830</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14842916</td><td>FAIL TO CONTROL SPEED --- ACC</td></tr><tr><td>14842923</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14842940</td><td>FAIL TO CONTROL SPEED</td></tr><tr><td>14842947</td><td>FAILED TO CONTROL SPEED</td></tr><tr><td>14842987</td><td>FAILED TO CONTROL SPEED</td></tr><tr><td>14843133</td><td>FAILED TO CONTROL SPEED</td></tr><tr><td>14843169</td><td>UNSAFE SPEED</td></tr><tr><td>14843236</td><td>UN ...

# %%
# Filtering Units with the filteredout_Conditioned dataframes
Units_with_filtered_conditions=Units_use_df\
.filter(col("VEH_COLOR_ID").isin(*units_with_top_10_colors) & col("VEH_LIC_STATE_ID").isin(*units_with_top_25_offences))\
.select("CRASH_ID","VEH_MAKE_ID","VEH_COLOR_ID","VEH_LIC_STATE_ID")

# Joining Dataframe filteredUnits and filteredCharges to find out top 5 vehicle makers with the given conditions
U3=Units_with_filtered_conditions.alias("U3")
C=charges_with_speed.alias("C")
UandC_Final=U3.join(C,[U3.CRASH_ID==C.CRASH_ID],"INNER")\
.groupBy("VEH_MAKE_ID")\
.agg(count("*").alias("Count_for_each_Veh_Makers"))\
.orderBy(col("Count_for_each_Veh_Makers").desc())\
.limit(5)\

display(UandC_Final)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VEH_MAKE_ID</th><th>Count_for_each_Veh_Makers</th></tr></thead><tbody><tr><td>FORD</td><td>9306</td></tr><tr><td>CHEVROLET</td><td>8279</td></tr><tr><td>TOYOTA</td><td>5276</td></tr><tr><td>DODGE</td><td>3952</td></tr><tr><td>NISSAN</td><td>3416</td></tr></tbody></table></div>
